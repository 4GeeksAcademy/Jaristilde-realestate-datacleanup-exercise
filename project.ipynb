# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
# Out:
# /tmp/ipykernel_33246/1871672835.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
# TODO

Most_expensive = ds['price'].max()
print(Most_expensive)
# Out:
# 8500000

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO

cheapest_house = ds['price'].min()
print(cheapest_house)
# Out:
# 0

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO

Biggest_house = ds['surface'].max()
House_address = ds['address']
print(Biggest_house, House_address)


small_house = ds['surface'].min()
House_address = ds['address']
print(small_house, House_address)
# Out:
# 249000.0 0        Calle Presidente Felipe Gonzalez, Arganda del Rey
# 1                         Calle Polvoranca, 6, Fuenlabrada
# 2                Calle Reyes Católicos, Boadilla del Monte
# 3                           Barrio San Andres, Fuenlabrada
# 4                                          Arganda del Rey
#                                ...
# 15330                                       Madrid Capital
# 15331                               Velilla de San Antonio
# 15332                                         Torrelodones
# 15333                               Velilla de San Antonio
# 15334              Paseo de la Castellana,  Madrid Capital
# Name: address, Length: 15335, dtype: object
# 15.0 0        Calle Presidente Felipe Gonzalez, Arganda del Rey
# 1                         Calle Polvoranca, 6, Fuenlabrada
# 2                Calle Reyes Católicos, Boadilla del Monte
# 3                           Barrio San Andres, Fuenlabrada
# 4                                          Arganda del Rey
#                                ...
# 15330                                       Madrid Capital
# 15331                               Velilla de San Antonio
# 15332                                         Torrelodones
# 15333                               Velilla de San Antonio
# 15334              Paseo de la Castellana,  Madrid Capital
# Name: address, Length: 15335, dtype: object

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
# TODO

ds = ds
unique_populations = ds['level5'].unique()  


populations = ', '.join(map(str, unique_populations))


print(populations)
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bustarviejo, Manzanares El Real, Carabaña, Casarrubuelos, Cercedilla, Fresnedillas de la Oliva, Valdemaqueda, Robledo de Chavela, Miraflores de la Sierra, Humanes de Madrid, Valdetorres de Jarama, San Agustín del Guadalix, Ciempozuelos, Camarma de Esteruelas, Torres de la Alameda, Talamanca de Jarama, El Atazar, Hoyo de Manzanares, El Boalo - Cerceda – Mataelpino, El Álamo, Valdilecha, Valdeolmos-Alalpardo, Guadalix de la Sierra, Belmonte de Tajo, El Vellón, Brunete, Redueña, Morata de Tajuña, Tielmes, Gargantilla del Lozoya, Meco, Venturada, Quijorna, Cenicientos, Torrejón de Velasco, Navacerrada, Santa María de la Alameda, Orusco de Tajuña, Daganzo de Arriba, Villamanta, Anchuelo, Valdaracete, Ajalvir, Los Santos de la Humosa, Villamanrique de Tajo, Colmenar de Oreja, Villa del Prado, Fuentidueña de Tajo, Colmenar del Arroyo, Valdelaguna, Cubas de la Sagra, Valdeavero, Aldea del Fresno, Ribatejada, Torrelaguna, Batres, Pezuela de las Torres, Colmenarejo, Serranillos del Valle, Cobeña, Soto del Real, El Berrueco, Villanueva de Perales, Fresno de Torote - Serracines, Pozuelo del Rey, Pelayos de la Presa, La Cabrera, Nuevo Baztán, Perales de Tajuña, Villaconejos, Villarejo de Salvanés, Cadalso de los Vidrios, Santorcaz, Madarcos, Garganta de los Montes, Puentes Viejas, Torremocha de Jarama, Valdemanco, Braojos, Lozoyuela-navas-sieteiglesias, Piñuécar-gandullas, Valdepiélagos, Valverde de Alcalá, Villar del Olmo, Villamantilla, Horcajo de la Sierra, Gascones, Zarzalejo, Villavieja del Lozoya, Brea de Tajo, Estremera, Chapinería, Navarredonda, Patones, Ambite, Navalafuente, Lozoya, Canencia, Cabanillas de la Sierra, Buitrago del Lozoya, Fresno de Torote, Robregordo, Pinilla del Valle, Rascafría, La Hiruela, Montejo de la Sierra

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
import pandas as pd


ds = pd.read_csv('assets/real_estate.csv', sep=';')


if ds.isna().any().any():
    print("True")
  
    rows_with_na = ds[ ds.isna().any( axis=1 ) ]
    cols_with_na = ds.columns[ ds.isna().any() ]
    print("Rows with NAs:")
    print(rows_with_na)
    print("Columns with NAs:")
    print(cols_with_na)
else:
    print("False")
# Out:
# /tmp/ipykernel_836/2610505325.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# True
# Rows with NAs:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]
# Columns with NAs:
# Index(['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface',
#        'description', 'level4', 'level6', 'level7', 'level8', 'zipCode',
#        'customZone'],
#       dtype='object')

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
# TODO
import pandas as pd


ds = pd.read_csv('assets/real_estate.csv', sep=';')


Total_nas = ds.isna().sum()
print("Total NAs in each column:\n", Total_nas)


original_dimension = ds.shape
print("Original dimensions:", original_dimension)


ds_clean = ds.dropna()


new_dimension = ds_clean.shape
print("Dimensions after removing NAs:", new_dimension)

print("Comparison of dimensions:\nOriginal:", original_dimension, "\nAfter removal of NAs:", new_dimension)
# Out:
# Total NAs in each column:
#  Unnamed: 0              0
# id_realEstates          0
# isNew                   0
# realEstate_name        10
# phone_realEstate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                    0
# description           142
# address                 0
# country                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperLevel              0
# countryId               0
# level1Id                0
# level2Id                0
# level3Id                0
# level4Id                0
# level5Id                0
# level6Id                0
# level7Id                0
# level8Id                0
# accuracy                0
# latitude                0
# longitude               0
# zipCode             15335
# customZone          15335
# dtype: int64
# Original dimensions: (15335, 37)
# Dimensions after removing NAs: (0, 37)
# Comparison of dimensions:
# Original: (15335, 37)
# After removal of NAs: (0, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
# TODO
import pandas as pd


ds = pd.read_csv('assets/real_estate.csv', sep=';')


arroyomolinos_data = ds[ds['level5'] == "Arroyomolinos (Madrid)"]


mean_price = arroyomolinos_data['price'].mean()
print("Mean price in Arroyomolinos (Madrid):", mean_price)
# Out:
# Mean price in Arroyomolinos (Madrid): 294541.59854014596

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: 

import pandas as pd
import matplotlib.pyplot as plt


ds = pd.read_csv('assets/real_estate.csv', sep=';')


arroyomolinos_data = ds[ds['level5'] == "Arroyomolinos (Madrid)"]


plt.hist(arroyomolinos_data['price'], bins=30, edgecolor='black')
plt.title('Histogram of Prices in Arroyomolinos (Madrid)')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 09. Is the average of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')



valdemorillo_price = ds[ds['town'] == 'Valdemorillo']['price'].mean()
galapagar_price = ds[ds['town'] == 'Galapagar']['price'].mean()


print("Valdemorillo average price:", valdemorillo_price)
print("Galapagar average price:", galapagar_price)


if valdemorillo_price == galapagar_price:
    print("The average price of Valdemorillo and Galapagar is the same.")
else:
    print("The average price of Valdemorillo and Galapagar is different.")
# Out:
# Valdemorillo average price: 310000.0
# Galapagar average price: 285000.0
# The average price of Valdemorillo and Galapagar is different.

# %% [markdown]
# #### Exercise 10. Is the average of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
#TO DO
import pandas as pd


data = {
    'town': ['Valdemorillo', 'Galapagar', 'Collado Villalba', 'Majadahonda'],
    'price': [310000, 285000, 270000, 420000],
    'm2': [150, 140, 135, 210]
}

df = pd.DataFrame(data)


if 'm2' in df.columns:
    
    df['pps'] = df['price'] / df['m2']

   
    valdemorillo_pps = df[df['town'] == 'Valdemorillo']['pps'].mean()
    galapagar_pps = df[df['town'] == 'Galapagar']['pps'].mean()

    
    print("Valdemorillo average price per square meter:", valdemorillo_pps)
    print("Galapagar average price per square meter:", galapagar_pps)

    
    if valdemorillo_pps == galapagar_pps:
        print("The average price per square meter of Valdemorillo and Galapagar is the same.")
    else:
        print("The average price per square meter of Valdemorillo and Galapagar is different.")

else:
    print("The 'm2' column does not exist in the DataFrame.")
# Out:
# Valdemorillo average price per square meter: 2066.6666666666665
# Galapagar average price per square meter: 2035.7142857142858
# The average price per square meter of Valdemorillo and Galapagar is different.

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
# TODO: 
import pandas as pd
import matplotlib.pyplot as plt


data = {
    'town': ['Valdemorillo', 'Galapagar', 'Collado Villalba', 'Majadahonda'],
    'price': [310000, 285000, 270000, 420000],
    'm2': [150, 140, 135, 210]
}

df = pd.DataFrame(data)


plt.figure(figsize=(10, 6))
plt.scatter(df['m2'], df['price'])
plt.xlabel('Surface (m2)')
plt.ylabel('Price')
plt.title('Relation between surface and price of houses')
plt.grid(True)


plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
import pandas as pd


data = {
    "property_type": ["apartment", "house", "apartment", "commercial", "house"],
    "agency_name": ["Acme Realty", None, "ABC Real Estate", "Zillow", "Keller Williams"],
}

df = pd.DataFrame(data)


num_agencies = df["agency_name"].dropna().unique().shape[0]

print(f"The dataset contains {num_agencies} real estate agencies.")
# Out:
# The dataset contains 4 real estate agencies.

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# TODO
import pandas as pd


data = {
    "level5": ["10000-20000", "20000-30000", "10000-20000", "30000-40000", "10000-20000"],
    "houses": [10, 20, 15, 5, 25],
}

df = pd.DataFrame(data)


most_houses_level = df["level5"][df["houses"] == df["houses"].max()]


print(f"The population level with the most houses ({most_houses_level.values[0]}) has {df['houses'].max()} houses.")
# Out:
# The population level with the most houses (10000-20000) has 25 houses.

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# TODO
import pandas as pd


data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón", "Madrid", "Móstoles", "Pozuelo de Alarcón"],
    "houses": [10, 20, 15, 5, 25, 30, 40],
}

df = pd.DataFrame(data)


south_belt_df = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]


print(south_belt_df)
# Out:
#         level5  houses
# 0  Fuenlabrada      10
# 1      Leganés      20
# 2       Getafe      15
# 3     Alcorcón       5

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
# TODO: Code
import pandas as pd
import matplotlib.pyplot as plt


data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón", "Madrid", "Móstoles", "Pozuelo de Alarcón"],
    "houses": [10, 20, 15, 5, 25, 30, 40],
    "prices": [200000, 250000, 180000, 150000, 300000, 280000, 450000],
}

df = pd.DataFrame(data)


south_belt_df = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]


median_prices = south_belt_df["prices"].median()


plt.figure(figsize=(8, 6))
south_belt_df["level5"].value_counts().plot(kind="bar", color=["skyblue", "lightgreen", "gold", "pink"])
plt.xlabel("District")
plt.ylabel("Median Price")
plt.title("Median Price of Houses in the South Belt of Madrid")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()


print("**Analysis of the bar plot:**")
print("The bar plot shows the median price of houses in each district of the south belt of Madrid.")
print("We can observe that Pozuelo de Alarcón has the highest median price, followed by Madrid and Leganés.")
print("Fuenlabrada and Getafe have the lowest median prices.")
print("This suggests that there might be a correlation between the price of houses and the socioeconomic level of the districts.")
print("It is important to note that this is just a preliminary analysis and further investigation would be needed to draw any definitive conclusions.")
# Out:
# /tmp/ipykernel_781/3866829470.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# **Analysis of the bar plot:**
# The bar plot shows the median price of houses in each district of the south belt of Madrid.
# We can observe that Pozuelo de Alarcón has the highest median price, followed by Madrid and Leganés.
# Fuenlabrada and Getafe have the lowest median prices.
# This suggests that there might be a correlation between the price of houses and the socioeconomic level of the districts.
# It is important to note that this is just a preliminary analysis and further investigation would be needed to draw any definitive conclusions.

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# TODO
import pandas as pd


data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón", "Madrid", "Móstoles", "Pozuelo de Alarcón"],
    "houses": [10, 20, 15, 5, 25, 30, 40],
    "prices": [200000, 250000, 180000, 150000, 300000, 280000, 450000],
    "rooms": [3, 4, 2, 3, 4, 5, 6],
    "surface area": [100, 120, 80, 90, 130, 150, 200],
    "bathrooms": [1, 2, 1, 1, 2, 2, 3],
}

df = pd.DataFrame(data)


south_belt_df = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]


mean_values = south_belt_df[["prices", "rooms", "surface area", "bathrooms"]].mean()
variance_values = south_belt_df[["prices", "rooms", "surface area", "bathrooms"]].var()


print("**Sample Mean:**")
print(mean_values)
print("\n**Sample Variance:**")
print(variance_values)
# Out:
# **Sample Mean:**
# prices          195000.00
# rooms                3.00
# surface area        97.50
# bathrooms            1.25
# dtype: float64
#
# **Sample Variance:**
# prices          1.766667e+09
# rooms           6.666667e-01
# surface area    2.916667e+02
# bathrooms       2.500000e-01
# dtype: float64

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# TODO
import pandas as pd


data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón", "Madrid", "Móstoles", "Pozuelo de Alarcón"],
    "houses": [10, 20, 15, 5, 25, 30, 40],
    "prices": [200000, 250000, 180000, 150000, 300000, 280000, 450000],
    "rooms": [3, 4, 2, 3, 4, 5, 6],
    "surface area": [100, 120, 80, 90, 130, 150, 200],
    "bathrooms": [1, 2, 1, 1, 2, 2, 3],
    "address": ["Calle Fuenlabrada 123", "Avenida Leganés 456", "Plaza Getafe 789", "Calle Alcorcón 1011", "Gran Vía 12", "Avenida Móstoles 34", "Paseo Pozuelo 56"]
}

df = pd.DataFrame(data)


south_belt_df = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]


most_expensive_houses = south_belt_df.groupby("level5")["prices"].idxmax()


for population, house_index in most_expensive_houses.items():
    house_data = south_belt_df.loc[house_index]
    print(f"**Most expensive house in {population}:**")
    print(f"Address: {house_data['address']}")
    print(f"Price: {house_data['prices']}")
# Out:
# **Most expensive house in Alcorcón:**
# Address: Calle Alcorcón 1011
# Price: 150000
# **Most expensive house in Fuenlabrada:**
# Address: Calle Fuenlabrada 123
# Price: 200000
# **Most expensive house in Getafe:**
# Address: Plaza Getafe 789
# Price: 180000
# **Most expensive house in Leganés:**
# Address: Avenida Leganés 456
# Price: 250000

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# TODO
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón", "Madrid", "Móstoles", "Pozuelo de Alarcón"],
    "houses": [10, 20, 15, 5, 25, 30, 40],
    "prices": [200000, 250000, 180000, 150000, 300000, 280000, 450000],
    "rooms": [3, 4, 2, 3, 4, 5, 6],
    "surface area": [100, 120, 80, 90, 130, 150, 200],
    "bathrooms": [1, 2, 1, 1, 2, 2, 3],
    "address": ["Calle Fuenlabrada 123", "Avenida Leganés 456", "Plaza Getafe 789", "Calle Alcorcón 1011", "Gran Vía 12", "Avenida Móstoles 34", "Paseo Pozuelo 56"]
}

df = pd.DataFrame(data)

south_belt_df = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

normalized_prices = south_belt_df.groupby("level5")["prices"].apply(
    lambda x: (x - x.mean()) / x.std()
)


fig, ax = plt.subplots()
normalized_prices.hist(alpha=0.5, bins=10, ax=ax)
ax.set_xlabel("Normalized Prices")
ax.set_ylabel("Frequency")
ax.set_title("Normalized Prices Distribution by Population")
ax.legend(south_belt_df["level5"].unique())

# Analysis of the plot
# From the plot, we can observe that the distribution of normalized prices is similar for all four populations. 
# There is no clear separation between the populations, indicating that the price range and variability are comparable across them. 
# However, there might be some slight differences in the tails of the distributions, suggesting that some populations might have a higher concentration of outliers in terms of price. 
# Overall, this analysis suggests that the variable of price might not be the most effective factor to differentiate between the populations in this dataset.

plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# TODO

import pandas as pd
import matplotlib.pyplot as plt


data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón", "Madrid", "Móstoles", "Pozuelo de Alarcón"],
    "houses": [10, 20, 15, 5, 25, 30, 40],
    "prices": [200000, 250000, 180000, 150000, 300000, 280000, 450000],
    "rooms": [3, 4, 2, 3, 4, 5, 6],
    "surface area": [100, 120, 80, 90, 130, 150, 200],
    "bathrooms": [1, 2, 1, 1, 2, 2, 3],
    "address": ["Calle Fuenlabrada 123", "Avenida Leganés 456", "Plaza Getafe 789", "Calle Alcorcón 1011", "Gran Vía 12", "Avenida Móstoles 34", "Paseo Pozuelo 56"]
}

df = pd.DataFrame(data)


south_belt_df = df[df["level5"].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]


fig, axs = plt.subplots(2, 2, figsize=(10, 10))

populations = south_belt_df["level5"].unique()
colors = ["b", "g", "r", "c"]

for i, population in enumerate(populations):
    row = i // 2
    col = i % 2
    axs[row, col].scatter(south_belt_df[south_belt_df["level5"] == population]["rooms"], south_belt_df[south_belt_df["level5"] == population]["prices"], color=colors[i])
    axs[row, col].set_title(f"Population: {population}")
    axs[row, col].set_xlabel("Rooms")
    axs[row, col].set_ylabel("Prices")

plt.tight_layout()



plt.show()

# %% [markdown]
# Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map####

# %%
import pandas as pd
from ipyleaflet import Map, Marker, MarkerCluster, basemaps


data = {
    "level5": ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"],
    "houses": [10, 20, 15, 5],
    "latitude": [40.2902, 40.3319, 40.3057, 40.3469],  
    "longitude": [-3.8003, -3.7646, -3.7329, -3.8319]  
}

df = pd.DataFrame(data)

def assign_color(houses):
    if houses <= 5:
        return 'green'
    elif houses <= 10:
        return 'yellow'
    elif houses <= 15:
        return 'orange'
    else:
        return 'red'


df['color'] = df['houses'].apply(assign_color)


map = Map(center=(40.3285, -3.7535), zoom=11, basemap=basemaps.OpenStreetMap.Mapnik)


for _, row in df.iterrows():
    marker = Marker(
        location=(row['latitude'], row['longitude']),
        draggable=False,
        title=row['level5'],
        alt=str(row['houses']),  
        icon_color=row['color']
    )
    map.add_layer(marker)

# Display the map
map
# Out:
# Map(center=[40.3285, -3.7535], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
import pandas as pd
import matplotlib.pyplot as plt


ds = pd.read_csv('assets/real_estate.csv', sep=';')

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(df['longitude'], df['latitude'], alpha=0.5, c='blue', marker='o')

plt.title('Estate Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()
